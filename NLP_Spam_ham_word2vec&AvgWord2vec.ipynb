# %%
# !pip install gensim

# %%
import gensim
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/Desktop/anaconda3/lib/python3.12/site-packages/gensim/matutils.py:1356
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Desktop/anaconda3/lib/python3.12/site-packages/gensim/corpora/_mmreader.pyx:11, in init gensim.corpora._mmreader()
#
# ImportError: cannot import name utils
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import gensim
#
# File ~/Desktop/anaconda3/lib/python3.12/site-packages/gensim/__init__.py:11
#       7 __version__ = '4.3.2'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
# ...

# %%
import gensim
print(gensim.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/Desktop/anaconda3/lib/python3.12/site-packages/gensim/matutils.py:1356
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Desktop/anaconda3/lib/python3.12/site-packages/gensim/corpora/_mmreader.pyx:11, in init gensim.corpora._mmreader()
#
# ImportError: cannot import name utils
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import gensim
#       2 print(gensim.__version__)
#
# File ~/Desktop/anaconda3/lib/python3.12/site-packages/gensim/__init__.py:11
#       7 __version__ = '4.3.2'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
# ...
