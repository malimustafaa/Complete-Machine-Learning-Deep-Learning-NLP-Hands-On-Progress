# %%
import sys
print(sys.executable)
# Out:
# /usr/local/bin/python3

# %%
# !pip install gensim

# %% [markdown]
# it was showing error and not downloading, so corrected it by downloading gensim on terminal on below given path
#
# /usr/local/bin/python3 -m pip install gensim

# %%
import sys
print(sys.version)
print(sys.executable)
# Out:
# 3.10.5 (v3.10.5:f377153967, Jun  6 2022, 12:36:10) [Clang 13.0.0 (clang-1300.0.29.30)]
# /usr/local/bin/python3

# %%
import gensim
print(gensim.__version__)
# Out:
# 4.3.3

# %%
from gensim.models import Word2Vec,KeyedVectors

# %%
import gensim.downloader as api

# %% [markdown]
# was throwing alot of error so done in collab
